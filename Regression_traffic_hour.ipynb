# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# load traffic data
traffic = pd.read_csv('LE5H.txt', sep='\t')
traffic.head(30)
# Out:
#     Unnamed: 0     tt_vf     pa_vf     tr_vf   tt   pa  tr       pa_pe  \
# 0      5010100  0.012643  0.013123  0.006098   91   88   3   96.703297
# 1      5010101  0.016394  0.016702  0.012197  118  112   6   94.915254
# 2      5010102  0.007086  0.007605  0.000000   51   51   0  100.000000
# 3      5010103  0.005280  0.005667  0.000000   38   38   0  100.000000
# 4      5010104  0.004307  0.004325  0.004066   31   29   2   93.548387
# 5      5010105  0.003751  0.003877  0.002033   27   26   1   96.296296
# 6      5010106  0.005974  0.006412  0.000000   43   43   0  100.000000
# 7      5010107  0.006530  0.006711  0.004066   47   45   2   95.744681
# 8      5010108  0.007641  0.007755  0.006098   55   52   3   94.545455
# 9      5010109  0.012226  0.012825  0.004066   88   86   2   97.727273
# 10     5010110  0.021813  0.021773  0.022361  157  146  11   92.993631
# 11     5010111  0.032789  0.034299  0.012197  236  230   6   97.457627
# 12     5010112  0.040152  0.042352  0.010164  289  284   5   98.269896
# 13     5010113  0.040569  0.042352  0.016262  292  284   8   97.260274
# 14     5010114  0.037373  0.039071  0.014230  269  262   7   97.397770
# 15     5010115  0.043209  0.044738  0.022361  311  300  11   96.463023
# 16     5010116  0.040986  0.043098  0.012197  295  289   6   97.966102
# 17     5010117  0.035289  0.036984  0.012197  254  248   6   97.637795
# 18     5010118  0.030566  0.032062  0.010164  220  215   5   97.727273
# 19     5010119  0.023758  0.024755  0.010164  171  166   5   97.076023
# 20     5010120  0.022924  0.023860  0.010164  165  160   5   96.969697
# 21     5010121  0.022230  0.023264  0.008131  160  156   4   97.500000
# 22     5010122  0.013893  0.014316  0.008131  100   96   4   96.000000
# 23     5010123  0.012087  0.012527  0.006098   87   84   3   96.551724
# 24     5010200  0.008197  0.008799  0.000000   59   59   0  100.000000
# 25     5010201  0.004585  0.004623  0.004066   33   31   2   93.939394
# 26     5010202  0.002501  0.002684  0.000000   18   18   0  100.000000
# 27     5010203  0.003057  0.003281  0.000000   22   22   0  100.000000
# 28     5010204  0.003195  0.002983  0.006098   23   20   3   86.956522
# 29     5010205  0.004585  0.004772  0.002033   33   32   1   96.969697
#
#         tr_pe  ntemp  ...  holiday  season      info  site index Unnamed: 24  \
# 0    3.296703  -22.8  ...       NY  winter  05SA0100  LE5H     1         NaN
# 1    5.084746  -22.1  ...       NY  winter  05SA0101  LE5H     2         NaN
# 2    0.000000  -22.2  ...       NY  winter  05SA0102  LE5H     3         NaN
# 3    0.000000  -20.6  ...       NY  winter  05SA0103  LE5H     4         NaN
# 4    6.451613  -20.6  ...       NY  winter  05SA0104  LE5H     5         NaN
# 5    3.703704  -20.4  ...       NY  winter  05SA0105  LE5H     6         NaN
# 6    0.000000  -20.1  ...       NY  winter  05SA0106  LE5H     7         NaN
# 7    4.255319  -19.9  ...       NY  winter  05SA0107  LE5H     8         NaN
# 8    5.454545  -19.9  ...       NY  winter  05SA0108  LE5H     9         NaN
# 9    2.272727  -20.0  ...       NY  winter  05SA0109  LE5H    10         NaN
# 10   7.006369  -19.9  ...       NY  winter  05SA0110  LE5H    11         NaN
# 11   2.542373  -19.6  ...       NY  winter  05SA0111  LE5H    12         NaN
# 12   1.730104  -19.5  ...       NY  winter  05SA0112  LE5H    13         NaN
# 13   2.739726  -19.1  ...       NY  winter  05SA0113  LE5H    14         NaN
# 14   2.602230  -19.3  ...       NY  winter  05SA0114  LE5H    15         NaN
# 15   3.536977  -19.7  ...       NY  winter  05SA0115  LE5H    16         NaN
# 16   2.033898  -19.6  ...       NY  winter  05SA0116  LE5H    17         NaN
# 17   2.362205  -19.5  ...       NY  winter  05SA0117  LE5H    18         NaN
# 18   2.272727  -19.5  ...       NY  winter  05SA0118  LE5H    19         NaN
# 19   2.923977  -19.6  ...       NY  winter  05SA0119  LE5H    20         NaN
# 20   3.030303  -19.5  ...       NY  winter  05SA0120  LE5H    21         NaN
# 21   2.500000  -19.5  ...       NY  winter  05SA0121  LE5H    22         NaN
# 22   4.000000  -20.6  ...       NY  winter  05SA0122  LE5H    23         NaN
# 23   3.448276  -23.6  ...       NY  winter  05SA0123  LE5H    24         NaN
# 24   0.000000  -25.6  ...      NAL  winter  05SU0100  LE5H    25         NaN
# 25   6.060606  -23.6  ...      NAL  winter  05SU0101  LE5H    26         NaN
# 26   0.000000  -27.4  ...      NAL  winter  05SU0102  LE5H    27         NaN
# 27   0.000000  -28.5  ...      NAL  winter  05SU0103  LE5H    28         NaN
# 28  13.043478  -29.7  ...      NAL  winter  05SU0104  LE5H    29         NaN
# 29   3.030303  -27.5  ...      NAL  winter  05SU0105  LE5H    30         NaN
#
#    Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN
#
# [30 rows x 29 columns]

# %%
# Define the features and target variables
features = ['ntemp','nwind', 'nvisi']
target = 'tr'

# %%
# Split the data into training and testing sets
train_data = traffic.sample(frac=0.8, random_state=1)
test_data = traffic.drop(train_data.index)
#train_data

# %%
# Train a linear regression model on the training data
reg = LinearRegression()
reg.fit(train_data[features], train_data[target])
# Out:
# LinearRegression()

# %%
# Predict traffic volume for the test data
predictions = reg.predict(test_data[features])

# %%
# Calculate the mean absolute error of the predictions
mae = abs(predictions - test_data[target]).mean()

print("Mean absolute error: ", mae)
# Out:
# Mean absolute error:  17.027323757865222
